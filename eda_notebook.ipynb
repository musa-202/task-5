# %% [markdown]
# # EDA Notebook for large_sales_dataset.csv
# This notebook was auto-generated. It contains the code used to perform basic exploratory data analysis, plus pointers for next steps.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"/mnt/data/large_sales_dataset.csv", low_memory=False)
print("Shape:", df.shape)
display(df.head())
display(df.describe(include='all').T)
display(df.isnull().sum().sort_values(ascending=False).head(20))

# %% [markdown]
# ## Visualizations
# The PDF `eda_report.pdf` (saved alongside this notebook) contains visualizations: correlation matrix, histograms, boxplots, scatterplots, and a findings page.
